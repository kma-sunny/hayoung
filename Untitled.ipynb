# %%
import pandas as pd

# %%
bus_data=pd.read_csv("data/BUS_STATION_BOARDING_MONTH_201812_201905.csv")
bus_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6664126 entries, 0 to 6664125
# Data columns (total 12 columns):
# Unnamed: 0    int64
# 사용일자          int64
# 노선ID          int64
# 노선번호          object
# 노선명           object
# 표준버스정류장ID     int64
# 버스정류장ARS번호    object
# 역ID           int64
# 역명            object
# 승차총승객수        int64
# 하차총승객수        int64
# 등록일자          int64
# dtypes: int64(8), object(4)
# memory usage: 610.1+ MB

# %%
bus_data.head()
# Out:
#    Unnamed: 0      사용일자      노선ID 노선번호                 노선명  표준버스정류장ID  \
# 0           0  20181201  41110087  440  440번(송파공영차고지~압구정동)  123000576
# 1           1  20181201  41110087  440  440번(송파공영차고지~압구정동)  123000575
# 2           2  20181201  41110087  440  440번(송파공영차고지~압구정동)  122000674
# 3           3  20181201  41110087  440  440번(송파공영차고지~압구정동)  121000002
# 4           4  20181201  41110087  440  440번(송파공영차고지~압구정동)  121000001
#
#   버스정류장ARS번호      역ID          역명  승차총승객수  하차총승객수      등록일자
# 0      24492  9013952  위례아이파크아파트앞      25     386  20181204
# 1      24495  9013951   송파꿈에그린아파트     439      24  20181204
# 2      23437  9013753      세곡푸르지오      29      18  20181204
# 3      22002  9006347     교육개발원입구     115     134  20181204
# 4      22001  9006346     교육개발원입구      62      74  20181204

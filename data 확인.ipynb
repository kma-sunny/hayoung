# %%
import pandas as pd

# %%
data=pd.read_csv("data/dataset_addSpot.csv")

# %%
data.isnull().sum()
# Out:
# unnamed                  0
# date                     0
# spot                     0
# temp_avg                 0
# temp_low                 0
# temp_high                0
# hum_avg                  0
# hum_low                  0
# hum_high                 0
# windSpeed_avg            0
# windSpeed_max            0
# rainfall                 0
# lat                      0
# long                     0
# spot_num               606
# alight_pasgr_num      4213
# ride_pasgr_num        4213
# traffic_sum         101607
# subway_input        101607
# subway_output       101607
# subway_sum          101607
# dtype: int64

# %%
data
# Out:
#         unnamed        date spot  temp_avg  temp_low  temp_high    hum_avg  \
# 0           214  20180101.0  동대문      -0.1      -4.1        3.8  44.500000
# 1           214  20180101.0  동대문      -0.1      -4.1        3.8  44.500000
# 2           214  20180101.0  동대문      -0.1      -4.1        3.8  44.500000
# 3           214  20180101.0  동대문      -0.1      -4.1        3.8  44.500000
# 4           214  20180101.0  동대문      -0.1      -4.1        3.8  44.500000
# 5           214  20180101.0  동대문      -0.1      -4.1        3.8  44.500000
# 6           214  20180101.0  동대문      -0.1      -4.1        3.8  44.500000
# 7           214  20180101.0  동대문      -0.1      -4.1        3.8  44.500000
# 8           214  20180101.0  동대문      -0.1      -4.1        3.8  44.500000
# 9           214  20180101.0  동대문      -0.1      -4.1        3.8  44.500000
# 10          214  20180101.0  동대문      -0.1      -4.1        3.8  44.500000
# ...

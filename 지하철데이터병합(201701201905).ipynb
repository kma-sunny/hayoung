# %%
import pandas as pd

# %% [markdown]
# CARD_SUBWAY_MONTH_201701.csv

# %%
data=pd.read_csv("data/지하철/CARD_SUBWAY_MONTH_201701.csv", encoding="euc-kr")

# %%
# try:
#     d=pd.read_csv("data/지하철/CARD_SUBWAY_MONTH_201703.csv", encoding="euc-kr")
# except:
#     d=pd.read_csv("data/지하철/CARD_SUBWAY_MONTH_201703.csv", encoding="utf-8")
# print(d)

# %%
 #pd.merge(data, pd.read_csv("data/지하철/CARD_SUBWAY_MONTH_201702.csv", encoding="euc-kr"))

# %%
mon=['02','03','04','05','06','07','08','09','10','11','12']
year=['2017']
stri="data/지하철/CARD_SUBWAY_MONTH_"

# %%
for y in range(1):
    for m in range(11):

            
        date=year[y]+mon[m]+".csv"
        filename=stri+date
        print(filename)
        #pd.read_csv(filename, encoding="euc-kr")
        
        try:
            d=pd.read_csv(filename, encoding="euc-kr")
        except:
            d=pd.read_csv(filename, encoding="utf-8")
            
        data=pd.concat([data,d])
# Out:
# data/지하철/CARD_SUBWAY_MONTH_201702.csv
# data/지하철/CARD_SUBWAY_MONTH_201703.csv
# data/지하철/CARD_SUBWAY_MONTH_201704.csv
# data/지하철/CARD_SUBWAY_MONTH_201705.csv
# data/지하철/CARD_SUBWAY_MONTH_201706.csv
# data/지하철/CARD_SUBWAY_MONTH_201707.csv
# data/지하철/CARD_SUBWAY_MONTH_201708.csv
# data/지하철/CARD_SUBWAY_MONTH_201709.csv
# data/지하철/CARD_SUBWAY_MONTH_201710.csv
# data/지하철/CARD_SUBWAY_MONTH_201711.csv
# data/지하철/CARD_SUBWAY_MONTH_201712.csv

# %%
data
# Out:
#               사용일자   노선명           역ID        역명    승차총승객수    하차총승객수  \
# 0         20170101   경원선          1907        가능    4194.0      3852
# 1         20170101   경원선          1908        녹양    2612.0      2468
# 2         20170101   경원선          1909        양주    5036.0      5004
# 3         20170101   경원선          1910        덕계    1145.0      1123
# 4         20170101   경원선          1911        덕정    3823.0      4188
# 5         20170101   경원선          1912        지행    4760.0      4674
# 6         20170101   경원선          1913     동두천중앙    2659.0      2521
# 7         20170101   경원선          1914        보산    1504.0      1575
# 8         20170101   경원선          1915       동두천    1238.0      1712
# 9         20170101   경원선          1916       소요산    4596.0      3796
# 10        20170101   경의선          1251       서울역    1212.0       787
# 11        20170101   경의선          1252        신촌     377.0       361
# 12        20170101   경의선          1261     효창공원앞     951.0      1055
# ...

# %%
pd.read_csv("data/지하철/CARD_SUBWAY_MONTH_201712.csv", encoding="utf-8")
# Out:
#            사용일자   노선명           역ID        역명    승차총승객수    하차총승객수  등록일자
# 20171201    경부선  1722           서정리    6052.0    5683.0  20171204   NaN
# 20171201    2호선   224            서초   26536.0   26469.0  20171204   NaN
# 20171201    중앙선  1207            양정     899.0     785.0  20171204   NaN
# 20171201    중앙선  1208            덕소    7199.0    7200.0  20171204   NaN
# 20171201    중앙선  1209            도심    3193.0    2465.0  20171204   NaN
# 20171201    중앙선  1210            팔당     705.0     680.0  20171204   NaN
# 20171201    중앙선  1211           운길산     754.0     647.0  20171204   NaN
# 20171201    중앙선  1212            양수    1972.0    2018.0  20171204   NaN
# 20171201    중앙선  1213            신원     238.0     180.0  20171204   NaN
# 20171201    중앙선  1214            국수    1069.0    1001.0  20171204   NaN
# 20171201    중앙선  1215            아신    1012.0     876.0  20171204   NaN
# 20171201    중앙선  1216            오빈     374.0     392.0  20171204   NaN
# ...
